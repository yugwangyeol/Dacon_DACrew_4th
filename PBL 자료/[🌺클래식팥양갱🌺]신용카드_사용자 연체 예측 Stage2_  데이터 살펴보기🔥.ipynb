# %% [markdown]
# # Stage 2 데이터 살펴보기

# %% [markdown]
# <img src='https://drive.google.com/uc?export=download&id=1ZofEHFAnpn-UpkHSwFOVCZeAUgVNS9el' width="" height ="" /><br>

# %% [markdown]
# # Intro

# %% [markdown]
# 우선 본격적으로 데이터를 살펴보기 전에 데이터를 한번 불러와볼까요?
#
# 지난 시간에 배운 것을 잘 복습하셨다면 이제 데이터를 불러오는 것은 어렵지 않을거에요!🤗

# %%
# pandas 불러오기
import pandas as pd
#train 데이터 불러오기
train = pd.read_csv('train.csv')
train
# Out:
#        index gender car reality  child_num  income_total  \
# 0          0      F   N       N          0      202500.0
# 1          1      F   N       Y          1      247500.0
# 2          2      M   Y       Y          0      450000.0
# 3          3      F   N       Y          0      202500.0
# 4          4      F   Y       Y          0      157500.0
# ...      ...    ...  ..     ...        ...           ...
# 26452  26452      F   N       N          2      225000.0
# 26453  26453      F   N       Y          1      180000.0
# 26454  26454      F   Y       N          0      292500.0
# 26455  26455      M   N       Y          0      171000.0
# 26456  26456      F   N       N          0       81000.0
#
#                 income_type                       edu_type  \
# 0      Commercial associate               Higher education
# 1      Commercial associate  Secondary / secondary special
# 2                   Working               Higher education
# ...

# %%
#test 데이터 불러오기
test = pd.read_csv('test.csv')
test
# Out:
#       index gender car reality  child_num  income_total           income_type  \
# 0     26457      M   Y       N          0      112500.0             Pensioner
# 1     26458      F   N       Y          0      135000.0         State servant
# 2     26459      F   N       Y          0       69372.0               Working
# 3     26460      M   Y       N          0      112500.0  Commercial associate
# 4     26461      F   Y       Y          0      225000.0         State servant
# ...     ...    ...  ..     ...        ...           ...                   ...
# 9995  36452      F   Y       Y          0      202500.0               Working
# 9996  36453      M   Y       Y          0      202500.0               Working
# 9997  36454      F   N       Y          0      292500.0               Working
# 9998  36455      F   Y       N          0      180000.0  Commercial associate
# 9999  36456      F   N       Y          0      270000.0               Working
#
# ...

# %%
#submission 데이터 불러오기
submission = pd.read_csv('sample_submission.csv')
submission
# Out:
#       index  0  1  2
# 0     26457  0  0  0
# 1     26458  0  0  0
# 2     26459  0  0  0
# 3     26460  0  0  0
# 4     26461  0  0  0
# ...     ... .. .. ..
# 9995  36452  0  0  0
# 9996  36453  0  0  0
# 9997  36454  0  0  0
# 9998  36455  0  0  0
# 9999  36456  0  0  0
#
# [10000 rows x 4 columns]

# %% [markdown]
# 본격적인 내용에 들어가기에 앞서, 데이터 분석을 처음 접하시는 분들은 의아해하실 수도 있는 Train, Test 데이터에 개념에 대해 설명드릴까 해요.
#
# Train Set은 모델을 학습하기 위한 DataSet으로, 오직 유일하게 Train 데이터만으로 학습을 진행해야 합니다.
#
# Test Set은 Validation 데이터로 어떤 모델을 사용할지를 결정한 후에
# 최종적으로 해당 모델의 예상 성능을 측정하기 위해 사용됩니다.
#
# ---
#
# <font color="coral">**그렇다면 왜 데이터를 Train과 Test로 나누어야 할까요?**</font>🤔
#
# Train 데이터는 우리가 알고 있는 정보이며,
# 우리의 최종 목적은 이미 알고 있는 정보를 통해 Unseen Data, 즉, 우리가 알고있지 않은 데이터를 예측 분류하는 것입니다.
# **<font color="green">따라서 현재 가지고 있는 데이터를 Train과 Test로 나눈 후 Train을 학습시켜 최적의 매개변수를 찾고,
# Test를 통해 모델의 성능을 평가합니다.</font>** 이때, Test 데이터가 Unseen Data의 역할을 하는 것이죠.

# %% [markdown]
# <img src='https://drive.google.com/uc?export=download&id=1uT8RBqCyDLexQK_5pr0pmznVOPRwfUeY' width="" height ="" /><br>
# 출처: https://towardsdatascience.com/train-test-split-and-cross-validation-in-python-80b61beca4b6

# %% [markdown]
# # 1. 데이터 타입 파악하기

# %% [markdown]
# 자 이제 데이터를 불러왔으니 본격적으로 데이터의 특징을 파악해보도록 할게요!😊
#
#
# 데이터 분석 과정에서 모델을 작성하기 전에 **<font color="green">데이터가 어떤 특징을 가지고 있는지 파악하고, 이를 어떻게 처리할건지 판단하는 작업</font>**은 매우 중요하답니다.
# 기본적으로 데이터 자체에 대한 해석이 잘못되면, 그 이후에 진행하는 모든 작업들이 모두 무용지물이 되버리기 때문인데요.
#
#
# 따라서 데이터를 <font color="coral">**'제대로'**</font>이해하는데에 많은 시간을 투자 할 필요가 있습니다!

# %% [markdown]
# 그렇다면 데이터 타입의 종류에는 어떤 것들이 있는지부터 알아볼 필요가 있을 것 같아요!
# 지난 시간에 배운 <font color="Sky Blue">**info() 함수**</font>를 이용한다면 우리가 가지고 있는 데이터의 타입을 알아 볼 수 있답니다.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          26457 non-null  int64
#  1   gender         26457 non-null  object
#  2   car            26457 non-null  object
#  3   reality        26457 non-null  object
#  4   child_num      26457 non-null  int64
#  5   income_total   26457 non-null  float64
#  6   income_type    26457 non-null  object
#  7   edu_type       26457 non-null  object
#  8   family_type    26457 non-null  object
#  9   house_type     26457 non-null  object
#  10  DAYS_BIRTH     26457 non-null  int64
#  11  DAYS_EMPLOYED  26457 non-null  int64
#  12  FLAG_MOBIL     26457 non-null  int64
#  13  work_phone     26457 non-null  int64
#  14  phone          26457 non-null  int64
#  15  email          26457 non-null  int64
#  16  occyp_type     18286 non-null  object
# ...

# %% [markdown]
# ---
# Dtype을 보면 int64, object, float64 이렇게 총 세가지 타입으로 구성되어 있는 것을 알 수 있는데요.
# 데이터는 데이터의 속성에 따라 분석하는 방법이 달라지기 때문에 구체적으로 데이터 타입의 종류에 대해 알아보도록 할게요!

# %% [markdown]
# **1. 수치형(Numerical)**
#
# '수치'라는 말에서 알 수 있듯이 수치형 데이터는 숫자로 이루어진 데이터입니다. 양적 변수라고 부르기도 하는데요!
# 수치형은 크게 이산형과 연속형으로 나눌 수 있어요.
#
#         1) 이산형(Descrete)
#         이산형 데이터는 변수가 가질 수 있는 값의 개수가 유한개이고 정수의 형태로 표현 가능한 데이터를 말합니다.
#         ex) 사람 수, 사고 건수
#
#         2) 연속형(Continuous)
#            연속형 데이터는 소수점으로 표현이 가능한 데이터입니다.
#         ex) 몸무게, 시간, 길이
# ---
# **2. 범주형(Categorical)**
#
# 범주형 데이터는 숫자로 측정할 수는 없지만, 여러 개의 값으로 나눌 수 있는 데이터입니다. 질적 변수라고 부르기도 하구요.
# 범주형은 크게 명목형과 순서형으로 나눌 수 있어요.
#
#         1) 명목형(Nominal)
#            명목형 데이터는 순서를 매길 수 없는 데이터입니다.
#          ex) 종교, 색깔, 성별
#
#         2) 순서형(Ordinal)
#            순서형 데이터는 데이터들이 어떤 기준에 따라 순서의 의미를 부여받은 데이터입니다.
#         ex) 월, 시간
# ---

# %% [markdown]
# 그렇다면 판다스 데이터 타입에서는 어떻게 표현될까요? 한번 알아보도록 합시다!
#
# - object: 문자열, 혹은 문자와 숫자가 혼합된 데이터
# - int: 수치형 데이터이며 정수 형태
# - float: 수치형 데이터이며 실수 형태
# - bool: 데이터가 참과 거짓 두 가지 값으로만 이루어진 경우
# - datetime: 날짜와 시간을 나타내는 데이터 타입
# - category: 범주형 데이터이며 순서 지정이 가능하고, object형보다 더 빠른 계산이 가능한 형태
# ---

# %% [markdown]
# 판다스에서는 이 데이터 타입을 필요에 따라 변환하는 기능을 제공하고 있어요.
#
# 그 전에 먼저 <font color="sky blue">**dtypes**</font>라는 속성에 대해 먼저 알아보도록 할게요!
# 각 열에 대해 데이터 타입과 결측값 개수, 인덱스 정보 등을 제공하는 info() 함수와는 다르게
# dtypes 속성은 데이터프레임 각 열의 자료형만을 제공합니다.
# 이 때, dtypes()처럼 메소드 형태로 사용하지 않아야 한다는 점 유의해주세요.
#
# 그럼 한번 적용해도록 합시다.

# %%
train.dtypes
# Out:
# index              int64
# gender            object
# car               object
# reality           object
# child_num          int64
# income_total     float64
# income_type       object
# edu_type          object
# family_type       object
# house_type        object
# DAYS_BIRTH         int64
# DAYS_EMPLOYED      int64
# FLAG_MOBIL         int64
# work_phone         int64
# phone              int64
# email              int64
# occyp_type        object
# family_size      float64
# begin_month      float64
# credit           float64
# dtype: object

# %% [markdown]
# 이렇게 각 열들이 무슨 데이터 타입을 가지고 있는지를 알 수 있는데요.
# 그렇다면 어떻게 기존의 데이터 타입을 원하는 데이터 타입으로 변환할 수 있을까요?
# 바로 <font color="sky blue">**astype 함수**</font>를 이용하면 됩니다!
# 이 함수는 데이터프레임 전체의 타입을 지정한 타입 형태로 한번에 바꿀 수 있도록 합니다.
#
# 그럼 한번 해볼까요?

# %%
#train의 데이터 타입을 object로 변경하여 할당
train = train.astype('object')
#train의 데이터 타입 확인
train.dtypes
# Out:
# index            object
# gender           object
# car              object
# reality          object
# child_num        object
# income_total     object
# income_type      object
# edu_type         object
# family_type      object
# house_type       object
# DAYS_BIRTH       object
# DAYS_EMPLOYED    object
# FLAG_MOBIL       object
# work_phone       object
# phone            object
# email            object
# occyp_type       object
# family_size      object
# begin_month      object
# credit           object
# dtype: object

# %% [markdown]
# 특정 열을 지정하여 데이터 타입을 변경 하는 것도 가능합니다.
#
# 예시를 볼게요.

# %%
train['child_num'] = train['child_num'].astype('float64')
train.dtypes
# Out:
# index              int64
# gender            object
# car               object
# reality           object
# child_num        float64
# income_total     float64
# income_type       object
# edu_type          object
# family_type       object
# house_type        object
# DAYS_BIRTH         int64
# DAYS_EMPLOYED      int64
# FLAG_MOBIL         int64
# work_phone         int64
# phone              int64
# email              int64
# occyp_type        object
# family_size      float64
# begin_month      float64
# credit           float64
# dtype: object

# %% [markdown]
# ### Inst.
# - train 데이터의 'begin_month' 열의 데이터 타입을 정수 형태로 바꿔보세요.
#
# - 데이터 타입을 다시 확인해보세요.

# %%
# train 데이터의 'begin_month' 열의 데이터 타입을 정수 형태로 바꿔보세요.

# 데이터 타입을 다시 확인해보세요.

# %% [markdown]
# ### Hint.
# - 정수 형태로 변경하려면 int64를 이용해야 합니다.

# %% [markdown]
# ### Solution.

# %%
train['begin_month'] = train['begin_month'].astype('int64')
train.dtypes
# Out:
# index              int64
# gender            object
# car               object
# reality           object
# child_num        float64
# income_total     float64
# income_type       object
# edu_type          object
# family_type       object
# house_type        object
# DAYS_BIRTH         int64
# DAYS_EMPLOYED      int64
# FLAG_MOBIL         int64
# work_phone         int64
# phone              int64
# email              int64
# occyp_type        object
# family_size      float64
# begin_month        int64
# credit           float64
# dtype: object

# %% [markdown]
# # 2. 데이터 클렌징

# %% [markdown]
# <img src='https://drive.google.com/uc?export=download&id=18ecUocfrAn6DYjLTnujzYsdbgW678f95' width="" height ="" /><br>

# %% [markdown]
# 다음은 본격적으로 데이터 전처리에 대해 알아보도록 할게요!
#
# 데이터를 분석하기 좋게 데이터를 고치는 모든 작업을 <font color="sky blue">**데이터 전처리(Data Preprocessing)**</font>이라고 합니다.
# 전처리는 분석 결과 및 모델 성능에 직접적인 영향을 미치기 때문에
# 모든 데이터 분석 프로젝트에서 <font color="coral">**'반드시'**</font> 거쳐야 하는 과정입니다.
#
# 실제로 한 설문조사에 의하면 분석가들은 데이터를 수집하고 전처리 하는데에
# 약 80% 이상의 시간을 투자한다고 답했을만큼 매우 중요한 작업이라고 할 수 있겠는데요.
#
# 이번 시간에는 데이터 전처리 과정 중에서도 <font color="sky blue">**데이터 클렌징(Data Cleansing)**</font>에 대해 알아보도록 하겠습니다.

# %% [markdown]
# ## 2.1 결측치 처리

# %% [markdown]
# 결측치란 데이터 내에 표기되지 않은 값을 의미합니다.
# 대부분의 머신러닝 알고리즘은 누락된 데이터가 있으면 제대로 된 역할을 하지 못하기 때문에
# 이에 대해 적절한 처리를 해주어야 합니다.
#
# **결측치는 미지의 값, 확정되지 않은 값을 의미하며 0이랑은 다르다는 점 주의해주세요!**
#
# 그렇다면 이 결측치는 어떻게 확인할 수 있을까요?
# 바로 <font color="sky blue">**isnull() 함수**</font>를 이용하면 간단하게 결측치 여부를 확인할 수 있습니다.

# %%
# train 데이터 결측치 여부
train.isnull()
# Out:
#        index  gender    car  reality  child_num  income_total  income_type  \
# 0      False   False  False    False      False         False        False
# 1      False   False  False    False      False         False        False
# 2      False   False  False    False      False         False        False
# 3      False   False  False    False      False         False        False
# 4      False   False  False    False      False         False        False
# ...      ...     ...    ...      ...        ...           ...          ...
# 26452  False   False  False    False      False         False        False
# 26453  False   False  False    False      False         False        False
# 26454  False   False  False    False      False         False        False
# 26455  False   False  False    False      False         False        False
# 26456  False   False  False    False      False         False        False
#
# ...

# %% [markdown]
# isnull() 함수는 결측 데이터면 True 값을, 아닌 데이터는 False 값을 반환해줍니다.
# 이 isnull() 함수에 sum() 함수를 더해준다면 간단하게 열 별 결측치 개수도 구할 수 있습니다.

# %%
# train 데이터 결측치 개수
train.isnull().sum()
# Out:
# index               0
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       8171
# family_size         0
# begin_month         0
# credit              0
# dtype: int64

# %% [markdown]
# 그렇다면 이러한 결측치는 어떻게 처리해야 할까요?
#
# 대표적인 결측치 처리 방법으로는 크게 제거와 대치가 있습니다.
# 그럼 자세히 알아볼까요?

# %% [markdown]
# ### 2.1.1 제거(Deletion)

# %% [markdown]
# 제거는 결측치 처리 방법 중 가장 간단한 방법으로 결측치가 포함된 행 전부 혹은 일부를 제거하는 것입니다.
# 샘플 수가 충분하다면 사용하는 것이 좋아요.
#
# Pandas에서 제공하는 dropna() 함수를 이용하면 쉽게 결측치를 제거할 수 있답니다.
# 예시를 한번 볼게요.

# %%
train.dropna()
# Out:
#        index gender car reality child_num income_total           income_type  \
# 1          1      F   N       Y         1     247500.0  Commercial associate
# 2          2      M   Y       Y         0     450000.0               Working
# 3          3      F   N       Y         0     202500.0  Commercial associate
# 4          4      F   Y       Y         0     157500.0         State servant
# 5          5      F   N       Y         2     270000.0               Working
# ...      ...    ...  ..     ...       ...          ...                   ...
# 26451  26451      F   N       Y         0     202500.0               Working
# 26452  26452      F   N       N         2     225000.0         State servant
# 26454  26454      F   Y       N         0     292500.0               Working
# 26455  26455      M   N       Y         0     171000.0               Working
# 26456  26456      F   N       N         0      81000.0               Working
#
# ...

# %% [markdown]
# 차이가 보이시나요?
#
# 결측치가 제거되어 원래 train 데이터와 비교했을때 행 개수가 달라진 것을 알 수 있습니다.
# 이때 괄호를 비워두거나 axis = 0 이라고 지정해주면 결측치가 있는 행이 삭제됩니다.
# 반대로 axis = 1이라고 지정해주면 결측치가 있는 열이 삭제됩니다.

# %%
train.dropna(axis=1)
# Out:
#        index gender car reality child_num income_total           income_type  \
# 0          0      F   N       N         0     202500.0  Commercial associate
# 1          1      F   N       Y         1     247500.0  Commercial associate
# 2          2      M   Y       Y         0     450000.0               Working
# 3          3      F   N       Y         0     202500.0  Commercial associate
# 4          4      F   Y       Y         0     157500.0         State servant
# ...      ...    ...  ..     ...       ...          ...                   ...
# 26452  26452      F   N       N         2     225000.0         State servant
# 26453  26453      F   N       Y         1     180000.0               Working
# 26454  26454      F   Y       N         0     292500.0               Working
# 26455  26455      M   N       Y         0     171000.0               Working
# 26456  26456      F   N       N         0      81000.0               Working
#
# ...

# %% [markdown]
# 여기서 하나 더 배워볼게요!
#
# dropna()에는 inplace라는 옵션이 있는데요.
# 이 옵션을 True라고 설정해주면 결측치 제거 상태를 데이터프레임에 저장하지 않고도 바로 적용된답니다.
# 참고해두면 유용하게 사용할 수 있을거에요.

# %% [markdown]
# 결측치를 제거하는 것은 가장 간단한 방법이긴 하지만 남용한다면 데이터를 왜곡할 가능성이 생기기 때문에
# 항상 신중하게 생각하고 작업하는게 좋아요.😇

# %% [markdown]
# ### Inst.
# - inplace를 True라고 설정했을 때와 안했을 때를 직접 비교해보세요.

# %%
# inplace를 True라고 설정했을 때

#설정 안했을 때

# %% [markdown]
# ### Hint
# - dropna를 사용하기 전 train 데이터를 다시 불러와야 합니다.

# %% [markdown]
# ### Solution.

# %%
#inplace =True
train = pd.read_csv('train.csv')
train.dropna(axis=1, inplace = True)
train
# Out:
#        index gender car reality  child_num  income_total  \
# 0          0      F   N       N          0      202500.0
# 1          1      F   N       Y          1      247500.0
# 2          2      M   Y       Y          0      450000.0
# 3          3      F   N       Y          0      202500.0
# 4          4      F   Y       Y          0      157500.0
# ...      ...    ...  ..     ...        ...           ...
# 26452  26452      F   N       N          2      225000.0
# 26453  26453      F   N       Y          1      180000.0
# 26454  26454      F   Y       N          0      292500.0
# 26455  26455      M   N       Y          0      171000.0
# 26456  26456      F   N       N          0       81000.0
#
#                 income_type                       edu_type  \
# 0      Commercial associate               Higher education
# 1      Commercial associate  Secondary / secondary special
# 2                   Working               Higher education
# ...

# %%
train = pd.read_csv('train.csv')
train.dropna(axis=1)
train
# Out:
#        index gender car reality  child_num  income_total  \
# 0          0      F   N       N          0      202500.0
# 1          1      F   N       Y          1      247500.0
# 2          2      M   Y       Y          0      450000.0
# 3          3      F   N       Y          0      202500.0
# 4          4      F   Y       Y          0      157500.0
# ...      ...    ...  ..     ...        ...           ...
# 26452  26452      F   N       N          2      225000.0
# 26453  26453      F   N       Y          1      180000.0
# 26454  26454      F   Y       N          0      292500.0
# 26455  26455      M   N       Y          0      171000.0
# 26456  26456      F   N       N          0       81000.0
#
#                 income_type                       edu_type  \
# 0      Commercial associate               Higher education
# 1      Commercial associate  Secondary / secondary special
# 2                   Working               Higher education
# ...

# %% [markdown]
# inplace = True 여부에 따라 열 개수가 달라지는 것을 확인할 수 있습니다.
#
# ---

# %% [markdown]
# #### 2.1.2 대치(Imputaion)

# %% [markdown]
# 대치란 결측치를 특정 값으로 대치하는 것으로, 도메인 지식이 있다면 보다 쉽게 처리가 가능합니다.
#
# 대치 값의 예시에 대해 알아보도록 합시다.

# %% [markdown]
# - 최빈값(mode): 범주형에서 주로 사용되며, 범주별 빈도가 가장 높은 값으로 대치
# - 중앙값(median): 숫자형에서 결측값을 제외한 중앙값으로 대치
# - 평균(mean): 숫자형에서 결측값을 제외한 평균으로 대치
# - 간단한 예측모델: 결측값이 없는 열로 구성된 데이터를 이용해 결측값이 있는 열 예측

# %% [markdown]
# Pandas에서 제공하는 <font color="sky blue">**fillna()함수**</font>를 이용하여 누락 데이터에 특정 값을 채울 수 있습니다.
#
# 예시를 한번 볼게요.

# %%
#결측값을 0으로 대치
train.fillna(0)
# Out:
#        index gender car reality  child_num  income_total  \
# 0          0      F   N       N          0      202500.0
# 1          1      F   N       Y          1      247500.0
# 2          2      M   Y       Y          0      450000.0
# 3          3      F   N       Y          0      202500.0
# 4          4      F   Y       Y          0      157500.0
# ...      ...    ...  ..     ...        ...           ...
# 26452  26452      F   N       N          2      225000.0
# 26453  26453      F   N       Y          1      180000.0
# 26454  26454      F   Y       N          0      292500.0
# 26455  26455      M   N       Y          0      171000.0
# 26456  26456      F   N       N          0       81000.0
#
#                 income_type                       edu_type  \
# 0      Commercial associate               Higher education
# 1      Commercial associate  Secondary / secondary special
# 2                   Working               Higher education
# ...

# %% [markdown]
# ## 2.2 이상치 처리

# %% [markdown]
# 이상치란 값의 범위가 일반적인 범위를 벗어나 특별한 값을 갖는 것을 말합니다.
# 데이터에 이상치가 있다면 이상치가 왜 발생했는지를 파악하는 것이 좋습니다.
#
# 그렇다면 이상치는 어떻게 관찰할 수 있을까요?

# %% [markdown]
#     1) 개별 데이터 관찰: 데이터 값을 눈으로 훑어보면서 전번적인 추세와 특이사항을 관찰
#     2) 요약 통계 지표 사용: 평균, 중앙값, 분산, 범위 등 적절한 요약 통계 지표를 이용
#     3) 시각화 활용: 히스토그램, 확률밀도 함수 등 다양한 그래프 이용

# %% [markdown]
# 구체적인 예를 한번 들어볼게요.
#
# 먼저 표준 변수로 변환하는 방법입니다.
# 평균이 0, 표준편차가 1인 분포로 변환하여 +3 이상이거나 -3 이하인 경우를 이상치로 처리할 수 있습니다.

# %% [markdown]
# <img src='https://drive.google.com/uc?export=download&id=1g5jWzL7XHJ5mb0769WV0ZzNe0NbpFNw9' width="" height ="" /><br>
# 출처: https://claryk.tistory.com/5

# %%
# 표준점수 기반 예제 코드
def std_based_outlier(df):
    for i in range(0, len(df.iloc[1])): 
        df.iloc[:,i] = df.iloc[:,i].replace(0, np.NaN) # optional
        df = df[~(np.abs(df.iloc[:,i] - df.iloc[:,i].mean()) > (3*df.iloc[:,i].std()))].fillna(0)

# %% [markdown]
# 혹은 IQR 방식을 이용하여 Q1 - 1.5*IQR 이하이거나 Q3 + 1.5*IQR 이상인 값을 이상치로 처리할 수 있습니다.
# 이때 박스 플롯을 이용하여 시각화 할 수 있는데, 우리는 아직 시각화를 배우지 않았기 때문에 일단 넘어가도록 할게요!

# %% [markdown]
# <img src='https://drive.google.com/uc?export=download&id=1ewQygwgwxytX_6UYsgjqZXmuG_2HVGeA' width="" height ="" /><br>
# 출처: https://hwi-doc.tistory.com/entry/IQR-%EB%B0%A9%EC%8B%9D%EC%9D%84-%EC%9D%B4%EC%9A%A9%ED%95%9C-%EC%9D%B4%EC%83%81%EC%B9%98-%EB%8D%B0%EC%9D%B4%ED%84%B0Outlier-%EC%A0%9C%EA%B1%B0

# %%
# IQR 기반 예제 코드
def outliers_iqr(df):
    quartile_1, quartile_3 = np.percentile(df, [25, 75])
    iqr = quartile_3 - quartile_1
    lower = quartile_1 - (iqr * 1.5)
    upper = quartile_3 + (iqr * 1.5)
    return np.where((df > upper) | (df < lower))

# %% [markdown]
# 위의 방법들을 이용하여 각 속성 값이 우리가 에측한 범위와 분포를 갖고 있는지를 확인하고
# 이상치를 파악하여 어떻게 대처할 지를 판단해야 하는데요.
# 이상치 처리는 크게 제거, 대치, 유지로 나눌 수 있습니다.
#
# 아무래도 도메인 지식이 어느정도 있다면 처리하기가 좀 더 용이하겠죠?

# %% [markdown]
# ## 2.3 중복 데이터 처리

# %% [markdown]
# 중복 데이터를 처리하기 위해서는 먼저 duplicated() 함수에 대해 알 필요가 있을 것 같아요.
# duplicated() 함수는 True, False의 boolean 형태를 반환합니다.
#
# 이를 응용한 함수인 drop_duplicates()를 이용한다면 중복 데이터를 쉽게 삭제할 수 있습니다.
# 괄호 안에는 중복을 처리하고 싶은 열 이름을 넣어주면 된답니다.
#
# 예시를 한번 볼까요?

# %%
#열 income_total내에 중복되는 값 제거
train.drop_duplicates(['income_total'])
# Out:
#        index gender car reality child_num income_total           income_type  \
# 0          0      F   N       N         0     202500.0  Commercial associate
# 1          1      F   N       Y         1     247500.0  Commercial associate
# 2          2      M   Y       Y         0     450000.0               Working
# 4          4      F   Y       Y         0     157500.0         State servant
# 5          5      F   N       Y         2     270000.0               Working
# ...      ...    ...  ..     ...       ...          ...                   ...
# 21173  21173      F   N       N         0     170302.5  Commercial associate
# 21697  21697      M   Y       N         0    1350000.0  Commercial associate
# 21823  21823      M   N       N         1     179271.0               Working
# 24757  24757      F   N       N         0     234135.0  Commercial associate
# 26191  26191      M   Y       N         0     191700.0               Working
#
# ...

# %% [markdown]
# ### Bonus Stage

# %% [markdown]
# 갑자기 보너스 스테이지가 나와서 놀라셨죠?🧐🧐
#
# 다음 챕터에서 배울 내용을 이해하려면 새로운 개념을 알아야 해서 보너스 스테이지를 마련해보았습니다!😊
#
# 바로 <font color="coral">**Scikit-Learn**</font>이라는 라이브러리입니다.
# 데이터 분석 및 머신러닝 적용을 위한 파이썬 기반의 라이브러리로 다양한 알고리즘과 프레임 워크, API를 제공합니다. 오랜기간 안정성이 검증되었으며 가장 강력한 라이브러리라고 생각하면 되는데요!
#
# 이 Scikit-Learn에서 제공하는 다양한 메서드 중, **fit**과 **transform**, **fit_transform**에 대한 개념을 짚고 넘어가도록 하겠습니다!

# %% [markdown]
# - fit: 데이터를 학습시키는 메서드로, 훈련 데이터에만 적용해 분포를 먼저 학습
# - transform: 실제로 학습시킨 것을 적용하는 메서드로, fit을 기준으로 얻은 분포에 맞춰 변형
# - fit_transform: fit과 transform이 결합된 단축 메서드

# %% [markdown]
# 이때 주의해야 할 점은 훈련 데이터에는 fit_transform 메서드를 적용하는 반면, <font color="coral">**테스트 데이터에는 transform 메서드만**</font>을 적용해야 한다는 것입니다.
#
# 테스트 데이터에도 fit을 해버리면 기존 학습 데이터에 fit한 기준을 다 무시하고 테스트 데이터까지 학습 해버려 테스트 데이터에 대한 새로운 분포값이 생성됩니다.
#
# 앞서 언급했듯 테스트 데이터는 성능 검증을 위해 단 한번만 사용해야 하는 데이터이므로 꼭 유의해주시길 바랄게요!
#
# 자 여기까지 이해하셨다면 이어서 다음 내용으로 가볼까요?

# %% [markdown]
# # 3. 데이터 변환

# %% [markdown]
# 데이터 클렌징에 이어서 데이터 전처리 과정 중 하나인 데이터 변환에 대해 알아보도록 하겠습니다.

# %% [markdown]
# ## 3.1 범수형 변수 처리하기

# %% [markdown]
# 데이터 분석 모형은 문자열 값을 입력값으로 처리하지 않기 때문에 범주형 데이터를 숫자로 변환해야할 필요가 있습니다.
#
# 여러가지 방법이 있겠지만 이번 시간에는 레이블 인코딩과 원핫 인코딩에 대해 배워보도록 하겠습니다.

# %% [markdown]
# ### 3.1.1 레이블 인코딩(LabelEncoding)

# %% [markdown]
# 레이블 인코딩은 문자열의 unique값을 숫자로 바꿔주는 방식입니다.
# 변수를 내림차순으로 정렬하여 번호를 부여하는데요.
#
# Scikit-Learn에서 제공하는 LabelEncoder를 사용하면 쉽게 구현이 가능합니다.
# 이때 위에서 언급한 fit과 transform 메서드가 사용됩니다.

# %% [markdown]
# <img src='https://drive.google.com/uc?export=download&id=1Vd9NpPvg5y2DzG1SXwMaKiTU4r5BcM4l' width="" height ="" /><br>
# 출처: https://tnqkrdmssjan.tistory.com/85

# %%
#LabelEncoder 사용을 위해 모듈 불러오기
from sklearn.preprocessing import LabelEncoder

#변수에 LabelEncoder 할당
le = LabelEncoder()

# 학습 진행
le.fit(train['car'])

# 적용
label = le.transform(train['car'])

print(label, type(label))
# Out:
# [0 0 1 ... 1 0 0] <class 'numpy.ndarray'>

# %% [markdown]
# ### Inst.
# 위의 코드를 fit_transform() 메서드로 표현해보세요.

# %%
#fit_transform()으로 표현해보기

# %% [markdown]
# ### Hint.
# fit_transform()은 fit과 transform이 결합된 단축 메서드입니다.

# %% [markdown]
# ### Solution.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

label = le.fit_transform(train['car'])


print(label, type(label))
# Out:
# [0 0 1 ... 1 0 0] <class 'numpy.ndarray'>

# %% [markdown]
# 레이블 인코딩을 사용할 때는 주의할 점이 있습니다.
#
# 숫자 값으로 변환되므로 독립적인 관측값 간에 관계성이 생길 가능성이 있고, 숫자를 가중치로 잘못 인식하여 값에 왜곡이 생길 수 있다는 것인데요. 이는 예측 성능의 저하를 유발할 수 있으므로 주의해야 합니다.
#
# 이를 보완하기 위해서는 원핫인코딩 방식을 사용할 수 있습니다.

# %% [markdown]
# ### 3.1.2 원핫 인코딩(OneHotEncoding)

# %% [markdown]
# 원핫 인코딩은 고유값들을 피쳐로 만들고 정답에 해당하는 열은 1로, 나머지는 0으로 표시하는 방식입니다. 아래 그림을 보면 쉽게 이해할 수 있을거에요.

# %% [markdown]
# <img src='https://drive.google.com/uc?export=download&id=10qRkxquf3EN-N83vVBNp8wIvD8uEUCdo' width="" height ="" /><br>
# 출처: https://www.researchgate.net/figure/An-example-of-one-hot-encoding_fig1_344409939
#
# ---

# %% [markdown]
# 원핫 인코딩 방식은 숫자의 크고 작은 특성(중요도)를 없애주므로 자주 사용됩니다.
#
# sklearn의 OneHotEncoder 클래스로 쉽게 사용 가능하지만 문자열에서는 바로 변환이 되지 않습니다. 따라서 라벨 인코더로 숫자로 변환을 한 후에 사용해야 합니다.
#
# 또한 입력값으로 2차원 데이터가 필요하므로 reshape()함수를 통해 형태를 변환해 주는 작업도 꼭 기억해주세요!
#
# 그럼 예시를 볼게요.

# %%
#사용할 모듈 불러오기
from sklearn.preprocessing import OneHotEncoder

#LabelEncoder 학습 및 적용
le = LabelEncoder()
le.fit(train['gender'])
label = le.transform(train['gender'])

# 2차원 데이터로 형태 변경
label = label.reshape(-1,1)

# 원핫인코더 학습 및 적용
oh_encoder = OneHotEncoder()
oh_encoder.fit(label)
oh_label = oh_encoder.transform(label)
print(oh_label.shape)
# Out:
# (26457, 2)

# %% [markdown]
# ### 3.1.3 get_dummies

# %% [markdown]
# get_dummies는 판다스의 내장함수로 위의 두 과정을 한번에 모두 처리해 주는 함수입니다. 별다른 설치 없이 손쉽게 실행이 가능합니다.
#
# 예시를 볼게요.

# %%
import pandas as pd
pd.get_dummies(train['gender'])
# Out:
#        F  M
# 0      1  0
# 1      1  0
# 2      0  1
# 3      1  0
# 4      1  0
# ...   .. ..
# 26452  1  0
# 26453  1  0
# 26454  1  0
# 26455  0  1
# 26456  1  0
#
# [26457 rows x 2 columns]

# %% [markdown]
# ### 3.2 데이터 스케일링

# %% [markdown]
# 대부분 학습에 이용되는 데이터들은 각 특성마다 데이터가 가질 수 있는 값의 범위가 다릅니다.대부분의 학습 알고리즘은 특성 별 데이터의 스케일이 다를 경우 잘 작동하지 않습니다. 따라서 데이터 값의 범위를 조정하는 스케일링 작업은 필수적입니다.

# %% [markdown]
# Scikit-Learn에서는 다음과 같은 다양한 스케일러를 제공합니다.
# - StandardScaler
# - RobustScaler
# - MinMaxScaler
# - MaxAbsScaler
#
# 네 가지 스케일러중 이번 시간에는 StandardScaler와 MinMaxScaler에 대해 다뤄보도록 하겠습니다.

# %% [markdown]
# ### 3.2.1 StandardScaler

# %% [markdown]
# 표준화라고도 하며, 데이터의 평균이 0, 분산이 1이 되도록 스케일링합니다. 표준화 진행 시 모든 특성들이 같은 스케일을 갖게 됩니다.

# %% [markdown]
# <img src='https://drive.google.com/uc?export=download&id=1zSYnFgTTECCnFq75zxkLMmA6DOTyK4T4' width="" height ="" /><br>
# 출처: https://jaaamj.tistory.com/20

# %%
from sklearn.preprocessing import StandardScaler

St_scaler = StandardScaler()

income_total_Standard_scaled = St_scaler.fit_transform(pd.DataFrame(train['income_total']))
print(income_total_Standard_scaled)
# Out:
# [[ 0.1491363 ]
#  [ 0.59084783]
#  [ 2.57854975]
#  ...
#  [ 1.03255937]
#  [-0.16006178]
#  [-1.04348485]]

# %% [markdown]
# ### 3.2.1 MinMaxScaler

# %% [markdown]
# 정규화라고도 하며, 데이터가 0과 1사이에 위치하도록 스케일링합니다. 이상치가 존재할 경우 스케일링 결과가 매우 좁은 범위로 압축될 수 있으므로 이상치에 민감합니다.

# %% [markdown]
# <img src='https://drive.google.com/uc?export=download&id=1aVOEbkx7qxLpHxw9XLFGmYGdBJSoDeCr' width="" height ="" /><br>
# 출처: https://jaaamj.tistory.com/20

# %%
from sklearn.preprocessing import MinMaxScaler

MM_scaler = MinMaxScaler()

income_total_scaled = MM_scaler.fit_transform(pd.DataFrame(train['income_total']))
print(income_total_scaled)
# Out:
# [[0.11337209]
#  [0.14244186]
#  [0.27325581]
#  ...
#  [0.17151163]
#  [0.09302326]
#  [0.03488372]]

# %% [markdown]
# ---

# %% [markdown]
# ### Inst.
# 위에서 배운 내용들을 모두 활용하여 전체 데이터에 대해 전처리를 진행해보세요.

# %% [markdown]
# ### Hint.
# 수치형 변수 열과 범주형 변수 열은 나누어서 따로 처리해주어야 합니다.

# %% [markdown]
# ### Solution.

# %%
#필요한 모듈 불러오기
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd   
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

from sklearn.model_selection import train_test_split

# 데이터 불러오기 
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

#결측치 처리
train=train.drop('occyp_type', axis=1)
test=test.drop('occyp_type', axis=1)

#범주형_이진 변수 처리
train['gender'] = train['gender'].replace(['F','M'],[0,1])
test['gender'] = test['gender'].replace(['F','M'],[0,1])

train['car'] = train['car'].replace(['N','Y'],[0,1])
test['car'] = test['car'].replace(['N','Y'],[0,1])

train['reality'] = train['reality'].replace(['N','Y'],[0,1])
test['reality'] = test['reality'].replace(['N','Y'],[0,1])

#범주형 변수 처리
train.loc[train['child_num'] >= 2,'child_num']=2
test.loc[test['child_num']>=2, 'child_num']=2

train['income_total'] = train['income_total'].astype(object)
train['income_total'] = train['income_total']/10000 
test['income_total'] = test['income_total']/10000

#범주형 변수 처리_레이블 인코딩
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()

train['income_type']=label_encoder.fit_transform(train['income_type'])
test['income_type']=label_encoder.transform(test['income_type'])

train['edu_type']=label_encoder.fit_transform(train['edu_type'])
test['edu_type']=label_encoder.transform(test['edu_type'])

train['family_type']=label_encoder.fit_transform(train['family_type'])
test['family_type']=label_encoder.transform(test['family_type'])

train['house_type']=label_encoder.fit_transform(train['house_type'])
test['house_type']=label_encoder.transform(test['house_type'])

train['income_total']=label_encoder.fit_transform(train['income_total'])
test['income_total']=label_encoder.fit_transform(test['income_total'])

#마이너스로 표현된 연속형 변수 처리
def make_bin(variable, n):
    train[variable]=-train[variable]
    test[variable]=-test[variable]
    count, bin_dividers =np.histogram(train[variable], bins=n) #train의 구간화를 적용
    bin_names=[str(i) for i in range(n)]
    train[variable]=pd.cut(x=train[variable], bins=bin_dividers, labels=bin_names, include_lowest=True)
    test[variable]=pd.cut(x=test[variable], bins=bin_dividers, labels=bin_names, include_lowest=True)
    test[variable].fillna(str(0), inplace=True) #test에는 없는 것을 임의의 값으로 채움
   
    train[variable]=label_encoder.fit_transform(train[variable])
    test[variable]=label_encoder.transform(test[variable])

make_bin('DAYS_BIRTH', n=10)
make_bin('DAYS_EMPLOYED', n=6)
make_bin('begin_month', n=4)

# %% [markdown]
# 위의 전처리 과정은 한 가지 예시일 뿐입니다.
#
# 배운 내용을 활용하여 다양하게 전처리를 진행해보세요!

# %% [markdown]
# # Outro

# %% [markdown]
# 자 이렇게 이번시간에 배울 내용이 모두 끝이 났습니다!😇
#
# 분량이 많다고 느껴질 수 있지만 데이터 분석의 초석이 되는 매우 중요한 내용들이므로 복습 열심히 하시길 바랄게요.😊😊
#
# 다음 시간에는 본격적으로 모델링에 대해 배워보도록 하겠습니다.
#
# 다음 시간에 만나요!
#
# 안녕~🥳🥳
